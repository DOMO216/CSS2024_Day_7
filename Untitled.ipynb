# %%
pip show sklearn
# Out:
# WARNING: Package(s) not found: sklearn
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn

# %%
print(sklearn.__version__)
# Out:
# 1.3.2

# %%
pip show sklearn
# Out:
# WARNING: Package(s) not found: sklearn
# Note: you may need to restart the kernel to use updated packages.

# %%
conda list
# Out:
# # packages in environment at /Users/thabangmolefi/opt/anaconda3:
# #
# # Name                    Version                   Build  Channel
# _ipyw_jlab_nb_ext_conf    0.1.0                    py38_0
# abseil-cpp                20211102.0           he9d5cce_0
# absl-py                   0.13.0                   pypi_0    pypi
# aiobotocore               2.5.0            py38hecd8cb5_0
# aiofiles                  22.1.0           py38hecd8cb5_0
# aiohttp                   3.8.5            py38h6c40b1e_0
# aioitertools              0.7.1              pyhd3eb1b0_0
# aiosignal                 1.2.0              pyhd3eb1b0_0
# aiosqlite                 0.18.0           py38hecd8cb5_0
# alabaster                 0.7.12             pyhd3eb1b0_0
# anaconda                  2023.09         py38_openblas_1
# anaconda-client           1.7.2                    py38_0
# anaconda-navigator        1.10.0                   py38_0
# anyio                     3.5.0            py38hecd8cb5_0
# ...

# %%
import sklearn
sklearn.__version__
# Out:
# '1.3.2'

# %%
# !upgrade scipip install --upgrade scikit-learn
